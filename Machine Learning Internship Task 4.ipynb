# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
import cv2

# %%
gesture_c = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_c"
gesture_down = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_down"
gesture_fist = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_fist"
gesture_fist_moved = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_fist_moved"
gesture_index = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_index"
gesture_I = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_l"
gesture_ok = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_ok"
gesture_palm = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_palm"
gesture_palm_moved = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_palm_moved"
gesture_thumb = r"D:\Prodigy internship\archive (1)\leapGestRecog\leapGestRecog\01\gesture_thumb"

# %%
data = []
label = []
size = (64,64)

# %%
for img in os.listdir(gesture_c):
    img1_path = os.path.join(gesture_c,img)
    img1 = cv2.imread(img1_path)
    if img1 is not None:
        img1_size = cv2.resize(img1,size)
        img1_color = cv2.cvtColor(img1_size,cv2.COLOR_BGR2GRAY)
        data.append(img1_color.flatten())
        label.append("c type finger")

for img in os.listdir(gesture_down):
    img2_path = os.path.join(gesture_down,img)
    img2 = cv2.imread(img2_path)
    if img2 is not None:
        img2_size = cv2.resize(img2,size)
        img2_color = cv2.cvtColor(img2_size,cv2.COLOR_BGR2GRAY)
        data.append(img2_color.flatten())
        label.append("down type finger")

for img in os.listdir(gesture_fist):
    img3_path = os.path.join(gesture_fist,img)
    img3 = cv2.imread(img3_path)
    if img3 is not None:
        img3_size = cv2.resize(img3,size)
        img3_color = cv2.cvtColor(img3_size,cv2.COLOR_BGR2GRAY)
        data.append(img3_color.flatten())
        label.append("fist type finger")

for img in os.listdir(gesture_fist_moved):
    img4_path = os.path.join(gesture_fist_moved,img)
    img4 = cv2.imread(img4_path)
    if img1 is not None:
        img4_size = cv2.resize(img4,size)
        img4_color = cv2.cvtColor(img4_size,cv2.COLOR_BGR2GRAY)
        data.append(img4_color.flatten())
        label.append("fist_moved type finger")

for img in os.listdir(gesture_index):
    img5_path = os.path.join(gesture_index,img)
    img5 = cv2.imread(img5_path)
    if img5 is not None:
        img5_size = cv2.resize(img5,size)
        img5_color = cv2.cvtColor(img5_size,cv2.COLOR_BGR2GRAY)
        data.append(img5_color.flatten())
        label.append("index type finger")

for img in os.listdir(gesture_I):
    img6_path = os.path.join(gesture_I,img)
    img6 = cv2.imread(img6_path)
    if img6 is not None:
        img6_size = cv2.resize(img6,size)
        img6_color = cv2.cvtColor(img6_size,cv2.COLOR_BGR2GRAY)
        data.append(img6_color.flatten())
        label.append("I type finger")

for img in os.listdir(gesture_ok):
    img7_path = os.path.join(gesture_ok,img)
    img7 = cv2.imread(img7_path)
    if img7 is not None:
        img7_size = cv2.resize(img7,size)
        img7_color = cv2.cvtColor(img7_size,cv2.COLOR_BGR2GRAY)
        data.append(img7_color.flatten())
        label.append("ok type finger")

for img in os.listdir(gesture_palm):
    img8_path = os.path.join(gesture_palm,img)
    img8 = cv2.imread(img8_path)
    if img8 is not None:
        img8_size = cv2.resize(img8,size)
        img8_color = cv2.cvtColor(img8_size,cv2.COLOR_BGR2GRAY)
        data.append(img8_color.flatten())
        label.append("palm type finger")

for img in os.listdir(gesture_palm_moved):
    img9_path = os.path.join(gesture_palm_moved,img)
    img9 = cv2.imread(img9_path)
    if img9 is not None:
        img9_size = cv2.resize(img9,size)
        img9_color = cv2.cvtColor(img9_size,cv2.COLOR_BGR2GRAY)
        data.append(img9_color.flatten())
        label.append("palm_moved type finger")

for img in os.listdir(gesture_thumb):
    img10_path = os.path.join(gesture_thumb,img)
    img10 = cv2.imread(img10_path)
    if img10 is not None:
        img10_size = cv2.resize(img10,size)
        img10_color = cv2.cvtColor(img10_size,cv2.COLOR_BGR2GRAY)
        data.append(img10_color.flatten())
        label.append("thumb type finger")

# %%
data
# Out:
# [array([4, 4, 4, ..., 3, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 2], dtype=uint8),
#  array([4, 5, 5, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 3, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([3, 4, 4, ..., 3, 4, 5], dtype=uint8),
#  array([5, 4, 5, ..., 3, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 3, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 6, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([3, 5, 3, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 5], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 5], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([6, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 3, 3], dtype=uint8),
#  array([3, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 3, ..., 4, 4, 3], dtype=uint8),
#  array([5, 3, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 6, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 3, 4, ..., 5, 4, 3], dtype=uint8),
#  array([3, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([4, 6, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 5, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 2], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 3, 3, ..., 4, 5, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 5], dtype=uint8),
#  array([4, 4, 6, ..., 3, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 3, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 5, 3], dtype=uint8),
#  array([5, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 2, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 4], dtype=uint8),
#  array([4, 3, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 5], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 3, 4], dtype=uint8),
#  array([4, 5, 3, ..., 4, 3, 4], dtype=uint8),
#  array([3, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 2], dtype=uint8),
#  array([4, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 3, 5, ..., 5, 4, 5], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 2, 3], dtype=uint8),
#  array([4, 4, 7, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 2], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 6, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 3, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 2], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 7, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([6, 5, 6, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 5], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 3, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 2, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 3, 3, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 6, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([3, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 2, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 3], dtype=uint8),
#  array([3, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([3, 4, 4, ..., 5, 5, 5], dtype=uint8),
#  array([6, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 2], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([3, 5, 4, ..., 3, 3, 2], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 2], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 3, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 3, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 6, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 5], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 5], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([6, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 6, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 4, 5], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 5, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 5], dtype=uint8),
#  array([4, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 6, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 3, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 5], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 5], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 6, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 5, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([4, 5, 6, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 5], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([3, 4, 4, ..., 5, 4, 5], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 6, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([3, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([6, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 2, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 2], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 6, 5, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([5, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 3, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 5], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 5], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 5, 3], dtype=uint8),
#  array([5, 3, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 3, 5, ..., 4, 4, 3], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 6, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 5], dtype=uint8),
#  array([3, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 3, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 6, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 2], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([5, 3, 4, ..., 4, 4, 3], dtype=uint8),
#  array([3, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([6, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 3, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 6, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 4], dtype=uint8),
#  array([4, 3, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([3, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 3, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 2, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 5, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 2], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 2], dtype=uint8),
#  array([4, 6, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 5, 5], dtype=uint8),
#  array([5, 6, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 4, ..., 3, 5, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 6, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 5, 5, 5], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 6, ..., 4, 5, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([3, 4, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 5], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 5], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 6, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 6, ..., 3, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 6, ..., 4, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 5], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 3, 3], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 3, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 6, 6, ..., 5, 3, 4], dtype=uint8),
#  array([4, 4, 3, ..., 4, 4, 4], dtype=uint8),
#  array([6, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 5, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 3, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 5], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 6, ..., 4, 5, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 4, 3, 3], dtype=uint8),
#  array([4, 4, 6, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 5, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 5, 4], dtype=uint8),
#  array([4, 4, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 6, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 5, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 3, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 4, ..., 5, 3, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 4, ..., 3, 5, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 4, 4, 3], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 3, 4], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 5, 4], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 3, 4], dtype=uint8),
#  array([4, 5, 4, ..., 3, 3, 4], dtype=uint8),
#  array([3, 4, 4, ..., 3, 4, 3], dtype=uint8),
#  array([5, 4, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 3, 5, ..., 4, 3, 4], dtype=uint8),
#  array([5, 4, 5, ..., 5, 4, 3], dtype=uint8),
#  array([5, 4, 5, ..., 4, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([6, 5, 4, ..., 4, 3, 4], dtype=uint8),
#  array([4, 4, 4, ..., 5, 4, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 3, 3], dtype=uint8),
#  array([5, 5, 4, ..., 5, 5, 4], dtype=uint8),
#  array([4, 5, 5, ..., 5, 5, 3], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 3, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 5, 4, 4], dtype=uint8),
#  array([4, 4, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([4, 5, 4, ..., 5, 3, 3], dtype=uint8),
#  array([4, 5, 5, ..., 4, 4, 4], dtype=uint8),
#  array([5, 4, 4, ..., 5, 4, 4], dtype=uint8),
#  array([5, 6, 5, ..., 4, 4, 4], dtype=uint8),
#  ...]

# %%
label
# Out:
# ['c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'c type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'down type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'fist_moved type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  'index type finger',
#  ...]

# %%
data = np.array(data)
label = np.array(label)

# %%
data
# Out:
# array([[4, 4, 4, ..., 3, 5, 4],
#        [4, 4, 4, ..., 4, 4, 3],
#        [5, 5, 5, ..., 4, 5, 4],
#        ...,
#        [4, 4, 4, ..., 5, 4, 4],
#        [4, 4, 5, ..., 4, 4, 4],
#        [5, 4, 4, ..., 4, 4, 3]], dtype=uint8)

# %%
label
# Out:
# array(['c type finger', 'c type finger', 'c type finger', ...,
#        'thumb type finger', 'thumb type finger', 'thumb type finger'],
#       dtype='<U22')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(data,label,test_size = 0.3, random_state = 42,stratify=label)

# %%
rf = RandomForestClassifier(n_estimators = 100)
rf
# Out:
# RandomForestClassifier()

# %%
fitting  = rf.fit(x_train,y_train)
fitting
# Out:
# RandomForestClassifier()

# %%
prediction = rf.predict(x_test)
prediction
# Out:
# array(['fist_moved type finger', 'I type finger', 'fist type finger',
#        'palm_moved type finger', 'fist_moved type finger',
#        'fist_moved type finger', 'fist type finger', 'index type finger',
#        'fist_moved type finger', 'fist_moved type finger',
#        'ok type finger', 'thumb type finger', 'palm_moved type finger',
#        'palm_moved type finger', 'palm type finger', 'down type finger',
#        'ok type finger', 'palm_moved type finger',
#        'palm_moved type finger', 'fist type finger',
#        'fist_moved type finger', 'fist_moved type finger',
#        'ok type finger', 'index type finger', 'palm_moved type finger',
#        'fist_moved type finger', 'index type finger', 'index type finger',
#        'thumb type finger', 'index type finger', 'fist_moved type finger',
#        'down type finger', 'fist_moved type finger', 'index type finger',
#        'fist_moved type finger', 'index type finger', 'palm type finger',
#        'fist_moved type finger', 'ok type finger', 'c type finger',
#        'fist type finger', 'down type finger', 'ok type finger',
#        'c type finger', 'palm type finger', 'down type finger',
#        'c type finger', 'palm type finger', 'fist type finger',
#        'c type finger', 'I type finger', 'ok type finger',
#        'down type finger', 'palm type finger', 'index type finger',
#        'down type finger', 'c type finger', 'palm_moved type finger',
#        'thumb type finger', 'fist_moved type finger',
#        'palm_moved type finger', 'fist_moved type finger',
#        'I type finger', 'thumb type finger', 'palm_moved type finger',
#        'fist_moved type finger', 'thumb type finger', 'ok type finger',
#        'palm type finger', 'palm type finger', 'fist_moved type finger',
#        'ok type finger', 'ok type finger', 'c type finger',
#        'fist type finger', 'I type finger', 'palm type finger',
#        'down type finger', 'fist_moved type finger', 'thumb type finger',
#        'I type finger', 'down type finger', 'ok type finger',
#        'fist type finger', 'fist type finger', 'I type finger',
#        'palm type finger', 'palm type finger', 'c type finger',
#        'palm type finger', 'down type finger', 'fist type finger',
#        'palm_moved type finger', 'fist type finger', 'ok type finger',
#        'ok type finger', 'ok type finger', 'index type finger',
#        'fist_moved type finger', 'c type finger',
#        'fist_moved type finger', 'fist type finger', 'I type finger',
#        'thumb type finger', 'fist type finger', 'fist type finger',
#        'c type finger', 'thumb type finger', 'index type finger',
#        'thumb type finger', 'down type finger', 'thumb type finger',
#        'palm_moved type finger', 'down type finger', 'fist type finger',
#        'index type finger', 'ok type finger', 'c type finger',
#        'palm_moved type finger', 'palm_moved type finger',
#        'I type finger', 'index type finger', 'c type finger',
#        'I type finger', 'ok type finger', 'c type finger',
#        'thumb type finger', 'c type finger', 'down type finger',
#        'fist_moved type finger', 'down type finger', 'I type finger',
#        'I type finger', 'palm_moved type finger', 'ok type finger',
#        'down type finger', 'palm_moved type finger', 'down type finger',
#        'palm_moved type finger', 'c type finger', 'palm type finger',
#        'palm_moved type finger', 'fist_moved type finger',
#        'palm_moved type finger', 'I type finger', 'index type finger',
#        'ok type finger', 'index type finger', 'down type finger',
#        'fist type finger', 'palm_moved type finger', 'palm type finger',
#        'palm type finger', 'c type finger', 'I type finger',
#        'fist_moved type finger', 'thumb type finger',
#        'palm_moved type finger', 'index type finger', 'c type finger',
#        'palm type finger', 'thumb type finger', 'palm type finger',
#        'c type finger', 'palm type finger', 'palm type finger',
#        'fist_moved type finger', 'fist_moved type finger',
#        'down type finger', 'palm_moved type finger', 'ok type finger',
#        'c type finger', 'fist type finger', 'ok type finger',
#        'ok type finger', 'palm type finger', 'index type finger',
#        'fist_moved type finger', 'index type finger', 'thumb type finger',
#        'I type finger', 'c type finger', 'ok type finger',
#        'palm type finger', 'c type finger', 'fist_moved type finger',
#        'thumb type finger', 'c type finger', 'palm_moved type finger',
#        'I type finger', 'c type finger', 'thumb type finger',
#        'fist_moved type finger', 'down type finger', 'c type finger',
#        'fist_moved type finger', 'fist_moved type finger',
#        'palm_moved type finger', 'I type finger', 'c type finger',
#        'palm type finger', 'palm_moved type finger', 'c type finger',
#        'down type finger', 'I type finger', 'c type finger',
#        'I type finger', 'ok type finger', 'palm type finger',
#        'fist type finger', 'fist type finger', 'c type finger',
#        'ok type finger', 'fist type finger', 'c type finger',
#        'c type finger', 'I type finger', 'index type finger',
#        'fist type finger', 'ok type finger', 'ok type finger',
#        'down type finger', 'c type finger', 'ok type finger',
#        'I type finger', 'fist_moved type finger', 'down type finger',
#        'ok type finger', 'palm_moved type finger', 'down type finger',
#        'index type finger', 'fist_moved type finger', 'c type finger',
#        'palm type finger', 'c type finger', 'I type finger',
#        'thumb type finger', 'thumb type finger', 'down type finger',
#        'thumb type finger', 'down type finger', 'I type finger',
#        'thumb type finger', 'thumb type finger', 'index type finger',
#        'ok type finger', 'index type finger', 'palm_moved type finger',
#        'index type finger', 'palm_moved type finger', 'index type finger',
#        'index type finger', 'fist type finger', 'index type finger',
#        'c type finger', 'fist type finger', 'c type finger',
#        'index type finger', 'thumb type finger', 'I type finger',
#        'fist type finger', 'index type finger', 'fist_moved type finger',
#        'index type finger', 'palm type finger', 'ok type finger',
#        'down type finger', 'palm type finger', 'down type finger',
#        'palm_moved type finger', 'fist_moved type finger',
#        'c type finger', 'I type finger', 'palm type finger',
#        'down type finger', 'palm type finger', 'palm_moved type finger',
#        'fist type finger', 'c type finger', 'palm type finger',
#        'fist type finger', 'palm type finger', 'down type finger',
#        'palm_moved type finger', 'palm type finger', 'thumb type finger',
#        'ok type finger', 'fist type finger', 'ok type finger',
#        'palm_moved type finger', 'index type finger', 'index type finger',
#        'down type finger', 'I type finger', 'fist type finger',
#        'ok type finger', 'palm_moved type finger', 'thumb type finger',
#        'fist_moved type finger', 'I type finger', 'I type finger',
#        'I type finger', 'down type finger', 'fist type finger',
#        'down type finger', 'ok type finger', 'palm_moved type finger',
#        'fist type finger', 'index type finger', 'fist type finger',
#        'down type finger', 'fist type finger', 'fist_moved type finger',
#        'palm type finger', 'c type finger', 'thumb type finger',
#        'palm type finger', 'fist_moved type finger', 'palm type finger',
#        'palm_moved type finger', 'palm_moved type finger',
#        'fist type finger', 'palm_moved type finger', 'fist type finger',
#        'down type finger', 'I type finger', 'ok type finger',
#        'fist type finger', 'fist_moved type finger', 'I type finger',
#        'palm_moved type finger', 'palm_moved type finger',
#        'thumb type finger', 'index type finger', 'fist_moved type finger',
#        'fist_moved type finger', 'c type finger', 'down type finger',
#        'index type finger', 'I type finger', 'palm_moved type finger',
#        'index type finger', 'ok type finger', 'I type finger',
#        'thumb type finger', 'down type finger', 'palm_moved type finger',
#        'c type finger', 'palm type finger', 'palm_moved type finger',
#        'thumb type finger', 'ok type finger', 'palm type finger',
#        'fist_moved type finger', 'palm_moved type finger',
#        'index type finger', 'palm type finger', 'palm_moved type finger',
#        'ok type finger', 'down type finger', 'index type finger',
#        'ok type finger', 'I type finger', 'palm type finger',
#        'thumb type finger', 'fist_moved type finger',
#        'palm_moved type finger', 'fist type finger', 'palm type finger',
#        'fist type finger', 'down type finger', 'palm type finger',
#        'c type finger', 'ok type finger', 'index type finger',
#        'down type finger', 'index type finger', 'palm type finger',
#        'I type finger', 'palm_moved type finger', 'palm type finger',
#        'fist type finger', 'fist type finger', 'palm_moved type finger',
#        'palm_moved type finger', 'palm type finger', 'fist type finger',
#        'fist type finger', 'fist_moved type finger', 'down type finger',
#        'thumb type finger', 'thumb type finger', 'I type finger',
#        'I type finger', 'index type finger', 'index type finger',
#        'palm type finger', 'fist_moved type finger',
#        'fist_moved type finger', 'down type finger', 'fist type finger',
#        'index type finger', 'I type finger', 'thumb type finger',
#        'c type finger', 'palm_moved type finger',
#        'fist_moved type finger', 'I type finger', 'ok type finger',
#        'I type finger', 'c type finger', 'palm_moved type finger',
#        'fist type finger', 'ok type finger', 'fist type finger',
#        'palm_moved type finger', 'down type finger', 'ok type finger',
#        'c type finger', 'fist type finger', 'index type finger',
#        'ok type finger', 'ok type finger', 'fist type finger',
#        'fist type finger', 'ok type finger', 'palm type finger',
#        'down type finger', 'I type finger', 'c type finger',
#        'fist type finger', 'down type finger', 'thumb type finger',
#        'thumb type finger', 'index type finger', 'ok type finger',
#        'palm type finger', 'c type finger', 'palm type finger',
#        'palm_moved type finger', 'ok type finger', 'down type finger',
#        'thumb type finger', 'c type finger', 'thumb type finger',
#        'down type finger', 'down type finger', 'down type finger',
#        'down type finger', 'thumb type finger', 'ok type finger',
#        'palm type finger', 'index type finger', 'ok type finger',
#        'palm type finger', 'palm_moved type finger', 'index type finger',
#        'c type finger', 'index type finger', 'fist type finger',
#        'fist_moved type finger', 'fist type finger', 'c type finger',
#        'fist_moved type finger', 'down type finger', 'thumb type finger',
#        'fist_moved type finger', 'palm type finger', 'c type finger',
#        'I type finger', 'thumb type finger', 'ok type finger',
#        'thumb type finger', 'thumb type finger', 'index type finger',
#        'fist_moved type finger', 'index type finger',
#        'palm_moved type finger', 'palm type finger', 'ok type finger',
#        'c type finger', 'I type finger', 'palm type finger',
#        'thumb type finger', 'palm type finger', 'I type finger',
#        'fist type finger', 'thumb type finger', 'fist type finger',
#        'I type finger', 'thumb type finger', 'index type finger',
#        'ok type finger', 'palm_moved type finger', 'ok type finger',
#        'ok type finger', 'down type finger', 'I type finger',
#        'thumb type finger', 'down type finger', 'down type finger',
#        'I type finger', 'I type finger', 'palm type finger',
#        'palm_moved type finger', 'I type finger', 'c type finger',
#        'palm type finger', 'I type finger', 'I type finger',
#        'fist type finger', 'thumb type finger', 'I type finger',
#        'fist_moved type finger', 'index type finger', 'I type finger',
#        'ok type finger', 'palm type finger', 'fist type finger',
#        'index type finger', 'fist type finger', 'I type finger',
#        'fist type finger', 'palm type finger', 'fist_moved type finger',
#        'thumb type finger', 'palm_moved type finger', 'c type finger',
#        'fist type finger', 'thumb type finger', 'palm type finger',
#        'palm type finger', 'index type finger', 'thumb type finger',
#        'thumb type finger', 'ok type finger', 'down type finger',
#        'ok type finger', 'c type finger', 'palm_moved type finger',
#        'thumb type finger', 'down type finger', 'c type finger',
#        'I type finger', 'fist_moved type finger', 'thumb type finger',
#        'index type finger', 'c type finger', 'index type finger',
#        'ok type finger', 'fist_moved type finger', 'ok type finger',
#        'fist_moved type finger', 'palm_moved type finger',
#        'c type finger', 'thumb type finger', 'thumb type finger',
#        'fist_moved type finger', 'down type finger', 'fist type finger',
#        'down type finger', 'fist type finger', 'down type finger',
#        'thumb type finger', 'I type finger', 'thumb type finger',
#        'I type finger', 'fist_moved type finger', 'c type finger',
#        'thumb type finger', 'index type finger', 'palm_moved type finger',
#        'c type finger', 'fist_moved type finger', 'ok type finger',
#        'I type finger', 'down type finger', 'index type finger',
#        'I type finger', 'fist_moved type finger', 'thumb type finger',
#        'fist type finger', 'fist type finger', 'fist_moved type finger',
#        'down type finger', 'index type finger', 'thumb type finger',
#        'index type finger', 'I type finger', 'palm type finger',
#        'c type finger', 'fist_moved type finger',
#        'palm_moved type finger', 'I type finger', 'palm type finger',
#        'index type finger', 'thumb type finger', 'down type finger',
#        'index type finger', 'c type finger'], dtype='<U22')

# %%
accuracy = accuracy_score(prediction , y_test)
accuracy
# Out:
# 1.0

# %%
print("The accuracy_score of hand gesture model is 1.0 , So it is the best predicted model for hand gesture machine")
# Out:
# The accuracy_score of hand gesture model is 1.0 , So it is the best predicted model for hand gesture machine
